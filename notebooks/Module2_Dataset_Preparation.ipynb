# %%
# AI Study Assistant

## Module 2 : Dataset Preparation

### Objectives

#- Load the generated datasets
#- Verify dataset structure
#- Check dataset quality
#- Prepare datasets for preprocessing

# %%
import pandas as pd
import os

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
print(os.getcwd())
# Out:
# C:\Users\ABC\Desktop\DATASET\notebooks

# %%
ap_df = pd.read_csv("../dataset/processed/antennas_and_propagation_dataset.csv")

es_df = pd.read_csv("../dataset/processed/embedded_systems_dataset.csv")

print("Datasets Loaded Successfully")
# Out:
# Datasets Loaded Successfully

# %%
print("Antennas Dataset")
ap_df.head()
# Out:
# Antennas Dataset
#                                             Question  \
# 0  Define the antenna term in different ways, and...
# 1  Draw and explain different parts of radiation ...
# 2  List down different types of antennas and expl...
# 3      Explain different types of antenna apertures.
# 4  Obtain the ratio of E_theta and H_phi field co...
#
#                     Subject                          Chapter  \
# 0  Antennas and Propagation        1. Basic antenna concepts
# 1  Antennas and Propagation        1. Basic antenna concepts
# 2  Antennas and Propagation        1. Basic antenna concepts
# 3  Antennas and Propagation        1. Basic antenna concepts
# 4  Antennas and Propagation  2. Radiation of Electric dipole
#
#                                       Years_Appeared  Frequency  \
# 0                           Summer 2023, Winter 2024          2
# 1                           Summer 2023, Winter 2024          2
# ...

# %%
print("Antennas Dataset")
es_df.head()
# Out:
# Antennas Dataset
#                                             Question           Subject  \
# 0  Define and classify Embedded Systems, and list...  Embedded Systems
# 1     Describe the components of an Embedded System.  Embedded Systems
# 2  Describe the skills required for an embedded s...  Embedded Systems
# 3  Describe an embedded processor as GPP, ASIP an...  Embedded Systems
# 4  List down the components available on SoC and ...  Embedded Systems
#
#                                Chapter  \
# 0  1. Introduction to Embedded Systems
# 1  1. Introduction to Embedded Systems
# 2  1. Introduction to Embedded Systems
# 3  1. Introduction to Embedded Systems
# 4  1. Introduction to Embedded Systems
#
#                                       Years_Appeared  Frequency  \
# 0  Summer 2022, Winter 2022, Winter 2023, Summer ...          6
# 1                                        Winter 2024          1
# 2  Winter 2021, Summer 2022, Summer 2023, Summer ...          4
# ...

# %%
print("Antennas Shape :", ap_df.shape)

print("Embedded Shape :", es_df.shape)
# Out:
# Antennas Shape : (64, 8)
# Embedded Shape : (90, 8)

# %%
ap_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Question        64 non-null     object
#  1   Subject         64 non-null     object
#  2   Chapter         64 non-null     object
#  3   Years_Appeared  64 non-null     object
#  4   Frequency       64 non-null     int64
#  5   Average_Marks   64 non-null     float64
#  6   Difficulty      64 non-null     object
#  7   Priority        64 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 4.1+ KB

# %%
es_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Question        90 non-null     object
#  1   Subject         90 non-null     object
#  2   Chapter         90 non-null     object
#  3   Years_Appeared  90 non-null     object
#  4   Frequency       90 non-null     int64
#  5   Average_Marks   90 non-null     float64
#  6   Difficulty      90 non-null     object
#  7   Priority        90 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.8+ KB

# %%
print(ap_df.columns.tolist())
# Out:
# ['Question', 'Subject', 'Chapter', 'Years_Appeared', 'Frequency', 'Average_Marks', 'Difficulty', 'Priority']

# %%
print(es_df.columns.tolist())
# Out:
# ['Question', 'Subject', 'Chapter', 'Years_Appeared', 'Frequency', 'Average_Marks', 'Difficulty', 'Priority']

# %%
print(ap_df.isnull().sum())
# Out:
# Question          0
# Subject           0
# Chapter           0
# Years_Appeared    0
# Frequency         0
# Average_Marks     0
# Difficulty        0
# Priority          0
# dtype: int64

# %%
print(es_df.isnull().sum())
# Out:
# Question          0
# Subject           0
# Chapter           0
# Years_Appeared    0
# Frequency         0
# Average_Marks     0
# Difficulty        0
# Priority          0
# dtype: int64

# %%
print("AP Duplicate Rows :", ap_df.duplicated().sum())

print("Embedded Duplicate Rows :", es_df.duplicated().sum())
# Out:
# AP Duplicate Rows : 0
# Embedded Duplicate Rows : 0

# %%
print("="*50)
print("Antennas Dataset Summary")
print("="*50)

print("Rows :", ap_df.shape[0])
print("Columns :", ap_df.shape[1])

print("="*50)

print("Embedded Dataset Summary")
print("="*50)

print("Rows :", es_df.shape[0])
print("Columns :", es_df.shape[1])
# Out:
# ...
# Antennas Dataset Summary
# ...
# Rows : 64
# Columns : 8
# ...
# Embedded Dataset Summary
# ...
# Rows : 90
# Columns : 8

# %%
ap_df.to_csv("../dataset/processed/verified_antennas_dataset.csv", index=False)

es_df.to_csv("../dataset/processed/verified_embedded_dataset.csv", index=False)

print("Verified Datasets Saved Successfully")
# Out:
# Verified Datasets Saved Successfully
